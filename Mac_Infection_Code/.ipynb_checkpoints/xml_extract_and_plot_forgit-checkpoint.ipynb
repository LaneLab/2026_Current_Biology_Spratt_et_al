# %%
from pathlib import Path
from trackmatexml import TrackmateXML
from matplotlib import pyplot as plt
import xarray as xr
import numpy as np
import pandas as pd
import os
import re
from collections import defaultdict
import pickle
from matplotlib.backends.backend_pdf import PdfPages
import matplotlib.pyplot as plt

# %%
# Read in .pkl file to create dictionary of tracks
output_dir = '/Users/Madison/Desktop/'
with open(os.path.join(output_dir, 'Tracked_Bacteria_Dict.pkl'), 'rb') as f:
    ds_all_dict = pickle.load(f)

ds_all_dict
# Out:
# {'20251024_XY001_final': <xarray.Dataset> Size: 3kB
#  Dimensions:                 (cell: 2, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 16B 1 2
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251024_XY001_final'
#      track                   <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 584B 236.0 234.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 584B 1.65e+03 1.875e+03 ... nan
#      Area                    (cell, time) float32 584B 21.0 14.5 19.5 ... nan nan
#      parents                 (cell) int64 16B 0 1
#      daughters               (cell, time) float32 584B nan nan nan ... nan nan,
#  '20251024_XY006_final': <xarray.Dataset> Size: 7kB
#  Dimensions:                 (cell: 5, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 40B 1 2 1 1 2
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251024_XY006_final'
#      track                   (cell) <U9 180B 'Track_74' ... 'Track_143'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 1kB 228.0 224.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 1kB 2.274e+03 2.672e+03 ... nan
#      Area                    (cell, time) float32 1kB 24.0 22.5 22.5 ... nan nan
#      parents                 (cell) int64 40B 0 1 0 0 1
#      daughters               (cell, time) float32 1kB nan nan nan ... nan nan nan,
#  '20251024_XY016_final': <xarray.Dataset> Size: 4kB
#  Dimensions:                 (cell: 3, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 24B 1 1 2
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251024_XY016_final'
#      track                   (cell) <U9 108B 'Track_46' 'Track_146' 'Track_146'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 876B 238.0 244.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 876B 2.215e+03 ... nan
#      Area                    (cell, time) float32 876B 22.5 22.5 21.5 ... nan nan
#      parents                 (cell) int64 24B 0 0 1
#      daughters               (cell, time) float32 876B nan nan nan ... nan nan,
#  '20251024_XY024_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                 (cell: 1, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 8B 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251024_XY024_final'
#      track                   <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 292B 226.0 221.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 292B 1.609e+03 ... nan
#      Area                    (cell, time) float32 292B 15.5 14.0 20.5 ... nan nan
#      parents                 (cell) int64 8B 0
#      daughters               (cell, time) float32 292B nan nan nan ... nan nan,
#  '20251027_XY007_final': <xarray.Dataset> Size: 3kB
#  Dimensions:                 (cell: 2, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 16B 1 2
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251027_XY007_final'
#      track                   <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 584B 270.0 263.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 584B 3.91e+03 4.594e+03 ... nan
#      Area                    (cell, time) float32 584B 26.5 25.0 28.0 ... nan nan
#      parents                 (cell) int64 16B 0 1
#      daughters               (cell, time) float32 584B nan nan nan ... nan nan,
#  '20251030_XY020_final': <xarray.Dataset> Size: 4kB
#  Dimensions:                 (cell: 3, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 24B 1 1 2
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251030_XY020_final'
#      track                   (cell) <U7 84B 'Track_0' 'Track_3' 'Track_3'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 876B 238.0 244.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 876B 2.825e+03 ... nan
#      Area                    (cell, time) float32 876B 16.5 16.0 18.5 ... nan nan
#      parents                 (cell) int64 24B 0 0 1
#      daughters               (cell, time) float32 876B nan nan nan ... nan nan,
#  '20251030_XY019_final': <xarray.Dataset> Size: 7kB
#  Dimensions:                 (cell: 5, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 40B 1 1 2 1 2
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251030_XY019_final'
#      track                   (cell) <U8 160B 'Track_0' 'Track_62' ... 'Track_83'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 1kB 294.0 275.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 1kB 2.603e+03 2.207e+03 ... nan
#      Area                    (cell, time) float32 1kB 6.5 8.5 4.0 ... nan nan nan
#      parents                 (cell) int64 40B 0 0 1 0 1
#      daughters               (cell, time) float32 1kB nan nan nan ... nan nan nan,
#  '20251030_XY016_final': <xarray.Dataset> Size: 3kB
#  Dimensions:                 (cell: 2, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 16B 1 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251030_XY016_final'
#      track                   (cell) <U7 56B 'Track_0' 'Track_3'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 584B 240.0 240.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 584B 2.063e+03 ... nan
#      Area                    (cell, time) float32 584B 14.5 17.0 11.0 ... nan nan
#      parents                 (cell) int64 16B 0 0
#      daughters               (cell, time) float32 584B nan nan nan ... nan nan,
#  '20251105_XY003_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                 (cell: 1, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 8B 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY003_final'
#      track                   <U7 28B 'Track_1'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 292B 296.0 306.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 292B 3.799e+03 ... nan
#      Area                    (cell, time) float32 292B 16.0 21.0 21.5 ... nan nan
#      parents                 (cell) int64 8B 0
#      daughters               (cell, time) float32 292B nan nan nan ... nan nan,
#  '20251105_XY005_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                 (cell: 1, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 8B 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY005_final'
#      track                   <U7 28B 'Track_2'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 292B 218.0 238.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 292B 3.2e+03 3.292e+03 ... nan
#      Area                    (cell, time) float32 292B 22.5 22.5 23.5 ... nan nan
#      parents                 (cell) int64 8B 0
#      daughters               (cell, time) float32 292B nan nan nan ... nan nan,
#  '20251105_XY007_final': <xarray.Dataset> Size: 3kB
#  Dimensions:                 (cell: 2, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 16B 1 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY007_final'
#      track                   (cell) <U7 56B 'Track_0' 'Track_2'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 584B 281.0 282.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 584B 1.741e+03 ... nan
#      Area                    (cell, time) float32 584B 8.0 9.0 9.0 ... nan nan
#      parents                 (cell) int64 16B 0 0
#      daughters               (cell, time) float32 584B nan nan nan ... nan nan,
#  '20251105_XY009_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                 (cell: 1, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 8B 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY009_final'
#      track                   <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 292B 293.0 264.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 292B 3.749e+03 ... nan
#      Area                    (cell, time) float32 292B 27.5 21.5 32.0 ... nan nan
#      parents                 (cell) int64 8B 0
#      daughters               (cell, time) float32 292B nan nan nan ... nan nan,
#  '20251105_XY011_final': <xarray.Dataset> Size: 3kB
#  Dimensions:                 (cell: 2, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 16B 1 2
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY011_final'
#      track                   <U8 32B 'Track_20'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 584B 237.0 244.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 584B 3.242e+03 ... nan
#      Area                    (cell, time) float32 584B 21.0 21.0 17.0 ... nan nan
#      parents                 (cell) int64 16B 0 1
#      daughters               (cell, time) float32 584B nan nan nan ... nan nan,
#  '20251105_XY013_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                 (cell: 1, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 8B 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY013_final'
#      track                   <U7 28B 'Track_3'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 292B 288.0 274.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 292B 2.867e+03 ... nan
#      Area                    (cell, time) float32 292B 11.5 15.5 14.5 ... nan nan
#      parents                 (cell) int64 8B 0
#      daughters               (cell, time) float32 292B nan nan nan ... nan nan,
#  '20251105_XY017_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                 (cell: 1, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 8B 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY017_final'
#      track                   <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 292B 266.0 287.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 292B 2.991e+03 ... nan
#      Area                    (cell, time) float32 292B 13.5 16.0 14.5 ... nan nan
#      parents                 (cell) int64 8B 0
#      daughters               (cell, time) float32 292B nan nan nan ... nan nan,
#  '20251105_XY018_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                 (cell: 1, time: 73)
#  Coordinates:
#    * cell                    (cell) int64 8B 1
#    * time                    (time) int64 584B 0 5 10 15 20 ... 345 350 355 360
#      position                <U20 80B '20251105_XY018_final'
#      track                   <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity    (cell, time) float32 292B 325.0 291.0 ... nan nan
#      TRITC_median_intensity  (cell, time) float32 292B 3.397e+03 ... nan
#      Area                    (cell, time) float32 292B 9.0 18.0 11.5 ... nan nan
#      parents                 (cell) int64 8B 0
#      daughters               (cell, time) float32 292B nan nan nan ... nan nan}

# %%
#make sure all of the cells have tracks in the same format (ie arrays of cell dimensions)
for key, ds in ds_all_dict.items():
    track = ds.coords['track'] 
    if track.ndim ==0:
        ds = ds.assign_coords(track=("cell", np.repeat(track.item(), ds.sizes['cell'])))
    ds_all_dict[key]=ds

# %%
def add_processed_data_to_dataset_dict(dataset_dict, data_var_to_modify, new_var_name, 
                                    interpolate = True, smooth = True, log_trans = False, 
                                     window_size = 3, save_dict=False):
    """
    goal here is to add a new data variable to the combined dataset dictionary
    dataset_dict is the dictionary of all the xarray datasets for each position
    data_var_to_modify is the data you want to you want to modify to create the new data variable
    new_var_name is name of the new data variable
    window_size is the size of moving window to use for the smoothing
    save_dict set to True if you want to save the updated dictionary - default is False - it is probably best to test things out first
    and you can always resave the dictionary outside of the function
    """

    for key, ds in dataset_dict.items():

        print(f"Running analysis on lineage: {key}")
        # ds is now our dataset - we don't need to select it
 
        # first get the GFP data or whatever variable you want to modify
        data = ds[data_var_to_modify]
        # normalize the data based on the background
        # interpolate the data - set fill_value to None to not go beyond edges I think
        if interpolate == True:
            data_interpolated = data.interpolate_na(dim='time', method='linear', fill_value=None,
                                                                    max_gap=1, use_coordinate=False)
        else:
            data_interpolated = data
        if smooth == True: 
            data_smoothed = data_interpolated.rolling(time=window_size, center=False, min_periods=1).mean()
        else:
            data_smoothed = data_interpolated
        
        # add the data to the ds
        ds[new_var_name] = data_smoothed
        #log transform and make a new array if you want one
        if log_trans ==True:
            ds[new_var_name+'_transformed'] = xr.apply_ufunc(np.log1p, ds[new_var_name])
        else:
            continue
    # save the data if save_dict = True
    if save_dict:
        with open(os.path.join(output_dir, 'all_datasets_dict.pkl'), 'wb') as f:
            pickle.dump(ds_all_dict, f)

    return dataset_dict

# %%
#Applying GFP modifications for plot
add_processed_data_to_dataset_dict(ds_all_dict,  'GFP_median_intensity', 
                                    'GFP_median_intensity_processed', log_trans = False,  
                                    window_size = 3, save_dict=False)
# Out:
# Running analysis on lineage: 20251024_XY001_final
# Running analysis on lineage: 20251024_XY006_final
# Running analysis on lineage: 20251024_XY016_final
# Running analysis on lineage: 20251024_XY024_final
# Running analysis on lineage: 20251027_XY007_final
# Running analysis on lineage: 20251030_XY020_final
# Running analysis on lineage: 20251030_XY019_final
# Running analysis on lineage: 20251030_XY016_final
# Running analysis on lineage: 20251105_XY003_final
# Running analysis on lineage: 20251105_XY005_final
# Running analysis on lineage: 20251105_XY007_final
# Running analysis on lineage: 20251105_XY009_final
# Running analysis on lineage: 20251105_XY011_final
# Running analysis on lineage: 20251105_XY013_final
# Running analysis on lineage: 20251105_XY017_final
# Running analysis on lineage: 20251105_XY018_final
# {'20251024_XY001_final': <xarray.Dataset> Size: 4kB
#  Dimensions:                         (cell: 2, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 16B 1 2
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251024_XY001_final'
#      track                           (cell) <U7 56B 'Track_0' 'Track_0'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 584B 236.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 584B 1.65e+03 ... nan
#      Area                            (cell, time) float32 584B 21.0 14.5 ... nan
#      parents                         (cell) int64 16B 0 1
#      daughters                       (cell, time) float32 584B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 584B 236.0 ... nan,
#  '20251024_XY006_final': <xarray.Dataset> Size: 8kB
#  Dimensions:                         (cell: 5, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 40B 1 2 1 1 2
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251024_XY006_final'
#      track                           (cell) <U9 180B 'Track_74' ... 'Track_143'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 1kB 228.0 224.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 1kB 2.274e+03 ... nan
#      Area                            (cell, time) float32 1kB 24.0 22.5 ... nan
#      parents                         (cell) int64 40B 0 1 0 0 1
#      daughters                       (cell, time) float32 1kB nan nan ... nan nan
#      GFP_median_intensity_processed  (cell, time) float32 1kB 228.0 226.0 ... nan,
#  '20251024_XY016_final': <xarray.Dataset> Size: 5kB
#  Dimensions:                         (cell: 3, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 24B 1 1 2
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251024_XY016_final'
#      track                           (cell) <U9 108B 'Track_46' ... 'Track_146'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 876B 238.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 876B 2.215e+03 ... nan
#      Area                            (cell, time) float32 876B 22.5 22.5 ... nan
#      parents                         (cell) int64 24B 0 0 1
#      daughters                       (cell, time) float32 876B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 876B 238.0 ... nan,
#  '20251024_XY024_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                         (cell: 1, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 8B 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251024_XY024_final'
#      track                           (cell) <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 292B 226.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 292B 1.609e+03 ... nan
#      Area                            (cell, time) float32 292B 15.5 14.0 ... nan
#      parents                         (cell) int64 8B 0
#      daughters                       (cell, time) float32 292B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 292B 226.0 ... nan,
#  '20251027_XY007_final': <xarray.Dataset> Size: 4kB
#  Dimensions:                         (cell: 2, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 16B 1 2
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251027_XY007_final'
#      track                           (cell) <U7 56B 'Track_0' 'Track_0'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 584B 270.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 584B 3.91e+03 ... nan
#      Area                            (cell, time) float32 584B 26.5 25.0 ... nan
#      parents                         (cell) int64 16B 0 1
#      daughters                       (cell, time) float32 584B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 584B 270.0 ... nan,
#  '20251030_XY020_final': <xarray.Dataset> Size: 5kB
#  Dimensions:                         (cell: 3, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 24B 1 1 2
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251030_XY020_final'
#      track                           (cell) <U7 84B 'Track_0' 'Track_3' 'Track_3'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 876B 238.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 876B 2.825e+03 ... nan
#      Area                            (cell, time) float32 876B 16.5 16.0 ... nan
#      parents                         (cell) int64 24B 0 0 1
#      daughters                       (cell, time) float32 876B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 876B 238.0 ... nan,
#  '20251030_XY019_final': <xarray.Dataset> Size: 8kB
#  Dimensions:                         (cell: 5, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 40B 1 1 2 1 2
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251030_XY019_final'
#      track                           (cell) <U8 160B 'Track_0' ... 'Track_83'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 1kB 294.0 275.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 1kB 2.603e+03 ... nan
#      Area                            (cell, time) float32 1kB 6.5 8.5 ... nan nan
#      parents                         (cell) int64 40B 0 0 1 0 1
#      daughters                       (cell, time) float32 1kB nan nan ... nan nan
#      GFP_median_intensity_processed  (cell, time) float32 1kB 294.0 284.5 ... nan,
#  '20251030_XY016_final': <xarray.Dataset> Size: 4kB
#  Dimensions:                         (cell: 2, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 16B 1 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251030_XY016_final'
#      track                           (cell) <U7 56B 'Track_0' 'Track_3'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 584B 240.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 584B 2.063e+03 ... nan
#      Area                            (cell, time) float32 584B 14.5 17.0 ... nan
#      parents                         (cell) int64 16B 0 0
#      daughters                       (cell, time) float32 584B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 584B 240.0 ... nan,
#  '20251105_XY003_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                         (cell: 1, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 8B 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY003_final'
#      track                           (cell) <U7 28B 'Track_1'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 292B 296.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 292B 3.799e+03 ... nan
#      Area                            (cell, time) float32 292B 16.0 21.0 ... nan
#      parents                         (cell) int64 8B 0
#      daughters                       (cell, time) float32 292B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 292B 296.0 ... nan,
#  '20251105_XY005_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                         (cell: 1, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 8B 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY005_final'
#      track                           (cell) <U7 28B 'Track_2'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 292B 218.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 292B 3.2e+03 ... nan
#      Area                            (cell, time) float32 292B 22.5 22.5 ... nan
#      parents                         (cell) int64 8B 0
#      daughters                       (cell, time) float32 292B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 292B 218.0 ... nan,
#  '20251105_XY007_final': <xarray.Dataset> Size: 4kB
#  Dimensions:                         (cell: 2, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 16B 1 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY007_final'
#      track                           (cell) <U7 56B 'Track_0' 'Track_2'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 584B 281.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 584B 1.741e+03 ... nan
#      Area                            (cell, time) float32 584B 8.0 9.0 ... nan
#      parents                         (cell) int64 16B 0 0
#      daughters                       (cell, time) float32 584B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 584B 281.0 ... nan,
#  '20251105_XY009_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                         (cell: 1, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 8B 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY009_final'
#      track                           (cell) <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 292B 293.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 292B 3.749e+03 ... nan
#      Area                            (cell, time) float32 292B 27.5 21.5 ... nan
#      parents                         (cell) int64 8B 0
#      daughters                       (cell, time) float32 292B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 292B 293.0 ... nan,
#  '20251105_XY011_final': <xarray.Dataset> Size: 4kB
#  Dimensions:                         (cell: 2, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 16B 1 2
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY011_final'
#      track                           (cell) <U8 64B 'Track_20' 'Track_20'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 584B 237.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 584B 3.242e+03 ... nan
#      Area                            (cell, time) float32 584B 21.0 21.0 ... nan
#      parents                         (cell) int64 16B 0 1
#      daughters                       (cell, time) float32 584B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 584B 237.0 ... nan,
#  '20251105_XY013_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                         (cell: 1, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 8B 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY013_final'
#      track                           (cell) <U7 28B 'Track_3'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 292B 288.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 292B 2.867e+03 ... nan
#      Area                            (cell, time) float32 292B 11.5 15.5 ... nan
#      parents                         (cell) int64 8B 0
#      daughters                       (cell, time) float32 292B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 292B 288.0 ... nan,
#  '20251105_XY017_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                         (cell: 1, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 8B 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY017_final'
#      track                           (cell) <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 292B 266.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 292B 2.991e+03 ... nan
#      Area                            (cell, time) float32 292B 13.5 16.0 ... nan
#      parents                         (cell) int64 8B 0
#      daughters                       (cell, time) float32 292B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 292B 266.0 ... nan,
#  '20251105_XY018_final': <xarray.Dataset> Size: 2kB
#  Dimensions:                         (cell: 1, time: 73)
#  Coordinates:
#    * cell                            (cell) int64 8B 1
#    * time                            (time) int64 584B 0 5 10 15 ... 350 355 360
#      position                        <U20 80B '20251105_XY018_final'
#      track                           (cell) <U7 28B 'Track_0'
#  Data variables:
#      GFP_median_intensity            (cell, time) float32 292B 325.0 ... nan
#      TRITC_median_intensity          (cell, time) float32 292B 3.397e+03 ... nan
#      Area                            (cell, time) float32 292B 9.0 18.0 ... nan
#      parents                         (cell) int64 8B 0
#      daughters                       (cell, time) float32 292B nan nan ... nan
#      GFP_median_intensity_processed  (cell, time) float32 292B 325.0 ... nan}

# %%
#plotting all cells, with selected cells highlighted as in figure
fig, ax = plt.subplots(figsize=(8, 5))
data_var='GFP_median_intensity_processed'
pos_to_color = ['20251105_XY017_final', '20251030_XY020_final', '20251030_XY016_final']
counter = 0
for key, ds in ds_all_dict.items():
    for track_name, ds_track in ds.groupby("track"):
        for cell in ds_track.cell.values:
            parent_value = ds_track.parents.sel(cell=cell)
            if parent_value ==0:
                var_values = ds_track[data_var].sel(cell=cell)
                non_nan_count = np.sum(~np.isnan(var_values))

                #print(non_nan_count)
                if non_nan_count > 12:
                  position = ds_track.position
                  if position.isin(pos_to_color) and track_name=='Track_0':
                    color = 'lime'
                    alpha = 1
                    linewidth = 1.5
                  else:
                     color = 'grey'
                     alpha = 0.5
                     linewidth = 1
                  counter += 1
                  style = 'solid' 
                  ax.plot(ds_track.time, var_values, color=color, alpha=alpha, linewidth = linewidth, linestyle= style)
                  ax.set_yscale('log')
                  ax.set_xlim(0, 240)
                  ax.set_xticks([0, 60, 120, 180, 240], minor=False)
                
            else:
                continue
print(counter)
plt.savefig(output_dir + '/Final_Tracks_Plot.pdf')
# Out:
# 24

# %%
#Plot individual tracks with their progeny (excluded in the plot above), rare cells have a division event that was trackable
data_var = 'GFP_median_intensity_processed'
# count how many tracks total
n_tracks = sum(
    len(ds.groupby("track"))
    for ds in ds_all_dict.values()
)

fig, axes = plt.subplots(
    n_tracks, 1,
    figsize=(4, 2 * n_tracks),
    sharex=True
)

# make axes iterable even if n_tracks == 1
axes = [axes] if n_tracks == 1 else axes

ax_idx = 0

for key, ds in ds_all_dict.items():
    for track_name, ds_track in ds.groupby("track"):

        ax = axes[ax_idx]

        for cell in ds_track.cell.values:
            var_values = ds_track[data_var].sel(cell=cell)
            parent_value = ds_track.parents.sel(cell=cell)
            if parent_value ==0:
                color = 'limegreen'
            else: 
                color = 'lightgrey' 
            alpha = 1 if ds_track.parents.sel(cell=cell)==0 else 0.5
            linewidth = 2 if ds_track.parents.sel(cell=cell)==0 else 0.75
            ax.plot(ds_track.time, var_values, color=color, alpha=alpha, linewidth = linewidth)
            ax.plot(ds_track.time, var_values, color=color, alpha=alpha, linewidth = linewidth)
            ax.set_xlim(0, 240)
            ax.set_ylim(100, 20000)
            ax.set_xticks([0, 60, 120, 180, 240], minor=False)
            

        ax.set_yscale("log")
        ax.set_title(f"{key} – Track {track_name}", fontsize=8)

        ax_idx += 1

plt.tight_layout()
plt.show()
